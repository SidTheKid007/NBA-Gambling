# %%
import pandas as pd 
import numpy as np 
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt 
df = pd.read_csv('CombinedBettingData2.csv')
df.head()
# Out:
#    Unnamed: 0 HomeTeam AwayTeam  HTWin  HTLoss    HT%  ATWin  ATLoss    AT%  \
# 0           0      LAC      GSW   31.0    19.0  0.620   43.0     7.0  0.860
# 1           1      PHX      LAC   15.0    34.0  0.306   31.0    18.0  0.633
# 2           2      PHI      LAC   16.0    27.0  0.372   30.0    17.0  0.638
# 3           3      ATL      LAC   26.0    19.0  0.578   30.0    16.0  0.652
# 4           4      LAC      LAL   28.0    14.0  0.667   15.0    29.0  0.341
#
#          Date  ...  Pinnacle Sports  5Dimes  Bookmaker  BetOnline  Bovada  \
# 0  2017-02-02  ...             -7.5    -7.5       -7.5       -7.5    -8.5
# 1  2017-02-01  ...             -2.5    -2.5       -2.5       -2.5    -3.0
# 2  2017-01-24  ...             -4.5    -4.5       -4.5       -4.5    -5.0
# 3  2017-01-23  ...              7.0     7.0        7.5        7.5     8.0
# 4  2017-01-14  ...             11.5    11.5       11.5       11.5    11.5
#
#    Heritage  Intertops  YouWager  JustBet  Sportsbetting
# 0      -8.0       -7.5      -8.0     -7.5           -7.5
# 1      -2.5       -2.5      -2.5     -2.5           -2.5
# 2      -4.5       -4.5      -4.5     -4.5           -4.5
# 3       7.5        7.5       7.5      7.5            7.5
# 4      11.5       11.5      11.5     11.5           11.5
#
# [5 rows x 21 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df = df.dropna()
df.columns
# Out:
# Index(['HomeTeam', 'AwayTeam', 'HTWin', 'HTLoss', 'HT%', 'ATWin', 'ATLoss',
#        'AT%', 'Date', 'WinMargin', 'Pinnacle Sports', '5Dimes', 'Bookmaker',
#        'BetOnline', 'Bovada', 'Heritage', 'Intertops', 'YouWager', 'JustBet',
#        'Sportsbetting'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Week'] = df['Date'].dt.week
df['Weekday'] = df['Date'].dt.dayofweek
df = df.sort_values(by=['Date'])
df = df.reset_index()
df = df.drop(['index','Date'], axis=1)
df.head()
# Out:
#   HomeTeam AwayTeam  HTWin  HTLoss  HT%  ATWin  ATLoss  AT%  WinMargin  \
# 0      OKC      ORL    1.0     0.0  1.0    0.0     1.0  0.0          8
# 1      NYK      BOS    1.0     0.0  1.0    0.0     1.0  0.0          2
# 2      DAL      MIA    0.0     1.0  0.0    1.0     0.0  1.0        -11
# 3      GSW      LAC    0.0     1.0  0.0    1.0     0.0  1.0        -19
# 4      LAL      CHI    0.0     1.0  0.0    1.0     0.0  1.0         -1
#
#    Pinnacle Sports  ...  Bovada  Heritage  Intertops  YouWager  JustBet  \
# 0              7.5  ...     7.5       8.0        7.5       7.5      7.5
# 1              4.5  ...     5.0       4.5        4.5       5.0      4.5
# 2             -4.5  ...    -5.5      -5.0       -4.5      -4.5     -4.5
# 3             -4.5  ...    -5.5      -4.0       -4.5      -4.5     -4.5
# 4             -5.0  ...    -5.5      -5.0       -5.0      -5.0     -5.5
#
#    Sportsbetting  Year  Month  Week  Weekday
# 0            7.5  2011     12    51        6
# 1            5.0  2011     12    51        6
# 2           -5.0  2011     12    51        6
# 3           -5.0  2011     12    51        6
# 4           -5.5  2011     12    51        6
#
# [5 rows x 23 columns]

# %%
df['average'] = (df['Pinnacle Sports'] + df['5Dimes'] + df['Bookmaker'] + df['BetOnline'] + df['Bovada'] + df['Heritage'] + df['Intertops'] + df['YouWager'] + df['JustBet'] + df['Sportsbetting'])/10
df.head()
# Out:
#   HomeTeam AwayTeam  HTWin  HTLoss  HT%  ATWin  ATLoss  AT%  WinMargin  \
# 0      OKC      ORL    1.0     0.0  1.0    0.0     1.0  0.0          8
# 1      NYK      BOS    1.0     0.0  1.0    0.0     1.0  0.0          2
# 2      DAL      MIA    0.0     1.0  0.0    1.0     0.0  1.0        -11
# 3      GSW      LAC    0.0     1.0  0.0    1.0     0.0  1.0        -19
# 4      LAL      CHI    0.0     1.0  0.0    1.0     0.0  1.0         -1
#
#    Pinnacle Sports  ...  Heritage  Intertops  YouWager  JustBet  \
# 0              7.5  ...       8.0        7.5       7.5      7.5
# 1              4.5  ...       4.5        4.5       5.0      4.5
# 2             -4.5  ...      -5.0       -4.5      -4.5     -4.5
# 3             -4.5  ...      -4.0       -4.5      -4.5     -4.5
# 4             -5.0  ...      -5.0       -5.0      -5.0     -5.5
#
#    Sportsbetting  Year  Month  Week  Weekday  average
# 0            7.5  2011     12    51        6     7.55
# 1            5.0  2011     12    51        6     4.70
# 2           -5.0  2011     12    51        6    -4.75
# 3           -5.0  2011     12    51        6    -4.70
# 4           -5.5  2011     12    51        6    -5.25
#
# [5 rows x 24 columns]

# %%
cols_at_end = ['WinMargin']
df = df[[c for c in df if c not in cols_at_end] + [c for c in cols_at_end if c in df]]
team = df.HomeTeam.unique()
team_dict = dict(zip(team, range(len(team))))
df1 = df.copy(deep=True)
df1 = df1.replace({'HomeTeam': team_dict})
df1 = df1.replace({'AwayTeam': team_dict})
df1.head()
# Out:
#    HomeTeam  AwayTeam  HTWin  HTLoss  HT%  ATWin  ATLoss  AT%  \
# 0         0         7    1.0     0.0  1.0    0.0     1.0  0.0
# 1         1        25    1.0     0.0  1.0    0.0     1.0  0.0
# 2         2        17    0.0     1.0  0.0    1.0     0.0  1.0
# 3         3        27    0.0     1.0  0.0    1.0     0.0  1.0
# 4         4        28    0.0     1.0  0.0    1.0     0.0  1.0
#
#    Pinnacle Sports  5Dimes  ...  Intertops  YouWager  JustBet  Sportsbetting  \
# 0              7.5     7.5  ...        7.5       7.5      7.5            7.5
# 1              4.5     4.5  ...        4.5       5.0      4.5            5.0
# 2             -4.5    -4.5  ...       -4.5      -4.5     -4.5           -5.0
# 3             -4.5    -4.5  ...       -4.5      -4.5     -4.5           -5.0
# 4             -5.0    -5.5  ...       -5.0      -5.0     -5.5           -5.5
#
#    Year  Month  Week  Weekday  average  WinMargin
# 0  2011     12    51        6     7.55          8
# 1  2011     12    51        6     4.70          2
# 2  2011     12    51        6    -4.75        -11
# 3  2011     12    51        6    -4.70        -19
# 4  2011     12    51        6    -5.25         -1
#
# [5 rows x 24 columns]

# %%
df2 = df1.copy(deep=True)
df2.loc[df2['WinMargin'] < 0, 'HTLoss'] = df2['HTLoss']-1
df2.loc[df2['WinMargin'] >= 0, 'HTWin'] = df2['HTWin']-1
df2.loc[df2['WinMargin'] < 0, 'ATWin'] = df2['ATWin']-1
df2.loc[df2['WinMargin'] >= 0, 'ATLoss'] = df2['ATLoss']-1
df2['HT%'] = df2['HTWin']/(df2['HTWin'] + df2['HTLoss'])
df2['AT%'] = df2['ATWin']/(df2['ATWin'] + df2['ATLoss'])
df2.head()
# Out:
#    HomeTeam  AwayTeam  HTWin  HTLoss  HT%  ATWin  ATLoss  AT%  \
# 0         0         7    0.0     0.0  NaN    0.0     0.0  NaN
# 1         1        25    0.0     0.0  NaN    0.0     0.0  NaN
# 2         2        17    0.0     0.0  NaN    0.0     0.0  NaN
# 3         3        27    0.0     0.0  NaN    0.0     0.0  NaN
# 4         4        28    0.0     0.0  NaN    0.0     0.0  NaN
#
#    Pinnacle Sports  5Dimes  ...  Intertops  YouWager  JustBet  Sportsbetting  \
# 0              7.5     7.5  ...        7.5       7.5      7.5            7.5
# 1              4.5     4.5  ...        4.5       5.0      4.5            5.0
# 2             -4.5    -4.5  ...       -4.5      -4.5     -4.5           -5.0
# 3             -4.5    -4.5  ...       -4.5      -4.5     -4.5           -5.0
# 4             -5.0    -5.5  ...       -5.0      -5.0     -5.5           -5.5
#
#    Year  Month  Week  Weekday  average  WinMargin
# 0  2011     12    51        6     7.55          8
# 1  2011     12    51        6     4.70          2
# 2  2011     12    51        6    -4.75        -11
# 3  2011     12    51        6    -4.70        -19
# 4  2011     12    51        6    -5.25         -1
#
# [5 rows x 24 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
cols = df2.columns
sc2 = StandardScaler()
df2 = df2.fillna(0)
for col in cols:
    df2[[col]] = sc2.fit_transform(df2[[col]])
df2.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#    HomeTeam  AwayTeam     HTWin    HTLoss       HT%     ATWin    ATLoss  \
# 0 -1.618782 -0.871963 -1.365621 -1.364642 -2.459188 -1.376533 -1.364264
# 1 -1.511539  1.058493 -1.365621 -1.364642 -2.459188 -1.376533 -1.364264
# 2 -1.404297  0.200512 -1.365621 -1.364642 -2.459188 -1.376533 -1.364264
# 3 -1.297054  1.272988 -1.365621 -1.364642 -2.459188 -1.376533 -1.364264
# 4 -1.189812  1.380235 -1.365621 -1.364642 -2.459188 -1.376533 -1.364264
#
#         AT%  Pinnacle Sports    5Dimes  ...  Intertops  YouWager   JustBet  \
# 0 -2.486068         0.698551  0.698655  ...   0.700096  0.696702  0.698385
# 1 -2.486068         0.236477  0.237693  ...   0.239199  0.314582  0.237108
# 2 -2.486068        -1.149745 -1.145193  ...  -1.143495 -1.137474 -1.146723
# 3 -2.486068        -1.149745 -1.145193  ...  -1.143495 -1.137474 -1.146723
# 4 -2.486068        -1.226757 -1.298847  ...  -1.220311 -1.213898 -1.300482
#
#    Sportsbetting      Year     Month      Week   Weekday   average  WinMargin
# 0       0.701321 -1.909198  1.508709  1.538777  1.528771  0.706162   0.385654
# 1       0.317511 -1.909198  1.508709  1.538777  1.528771  0.269420  -0.059762
# 2      -1.217728 -1.909198  1.508709  1.538777  1.528771 -1.178727  -1.024829
# 3      -1.217728 -1.909198  1.508709  1.538777  1.528771 -1.171065  -1.618717
# 4      -1.294490 -1.909198  1.508709  1.538777  1.528771 -1.255349  -0.282470
#
# [5 rows x 24 columns]

# %%
df3 = df2.copy(deep=True)
#df3 = df3.drop(['Date'], axis=1)

# %%
train=df3[0:(round(len(df3)*.8))] 
test=df3[(round(len(df3)*.8)):]
trains = np.split(train, [23], axis=1)
train_x=trains[0]
train_y=trains[1]
tests = np.split(test, [23], axis=1)
test_x=tests[0]
test_y=tests[1]

# %%
def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

# %%
train_y.head()
# Out:
#    WinMargin
# 0   0.385654
# 1  -0.059762
# 2  -1.024829
# 3  -1.618717
# 4  -0.282470

# %% [markdown]
# ## Correlation Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

d = df3

corr = d.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

print(sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.01, cbar_kws={"shrink": .5}))
# Out:
# AxesSubplot(0.127273,0.125;0.617727x0.755)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_x.values, train_y.values)
#reg.score(train_x.values, train_y.NBAPTS.values)

reg.coef_
# Out:
# array([[-0.01382449, -0.01587515, -0.10088212, -0.10869107, -0.0098526 ,
#          0.10848247,  0.07897661,  0.01327902,  0.37135113, -0.13517607,
#          0.07535534, -0.57779352, -0.26819402, -0.02489319,  0.16493803,
#          0.05655197,  0.24315399,  0.53630173,  0.0315353 , -0.07349257,
#          0.05149109,  0.03209092,  0.04311386]])

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(reg.predict(train_x.values))
test_y2['prediction'] = sc2.inverse_transform(reg.predict(test_x.values))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'Linear Regression Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'Linear Regression Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'Linear Regression Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'Linear Regression Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.22127078726870308
# train mse = 139.4886012130452
# adj test r^2 = 0.19071984609751125
# test mse = 151.873690974978

# %%
from sklearn.metrics import accuracy_score
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 68.37%
# The testing accuracy is 67.93%

# %% [markdown]
# ## Naive Model

# %%
one = (len(train_y3[train_y3['Over']>.5]) + len(test_y3[test_y3['Over']>.5])) / (len(train_y3) + len(test_y3)) * 100
zero = (len(train_y3[train_y3['Over']<.5]) + len(test_y3[test_y3['Over']<.5])) / (len(train_y3) + len(test_y3)) * 100

# %%
print('Always picking over the line works ' + str(round(one,2)) + '% of the time')
print('Always picking under the line works ' + str(round(zero,2)) + '% of the time')
# Out:
# Always picking over the line works 58.72% of the time
# Always picking under the line works 41.28% of the time

# %% [markdown]
# ## Extra Trees

# %%
from sklearn.ensemble import ExtraTreesRegressor
reg = ExtraTreesRegressor(n_estimators=1000,bootstrap=True)
reg.fit(train_x.values, train_y.values)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# ExtraTreesRegressor(bootstrap=True, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#           oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(reg.predict(train_x.values))
test_y2['prediction'] = sc2.inverse_transform(reg.predict(test_x.values))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'Extra Trees Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'Extra Trees Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'Extra Trees Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'Extra Trees Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.8883531469248209
# train mse = 19.998560617333332
# adj test r^2 = 0.14217118698839093
# test mse = 160.98458293894492

# %%
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 96.13%
# The testing accuracy is 64.26%

# %% [markdown]
# ## Random Forrest

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(n_estimators=1000)
reg.fit(train_x.values, train_y.WinMargin.values)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(reg.predict(train_x.values))
test_y2['prediction'] = sc2.inverse_transform(reg.predict(test_x.values))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'Random Forrest Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'Random Forrest Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'Random Forrest Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'Random Forrest Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.8875529578568334
# train mse = 20.14189318014815
# adj test r^2 = 0.1360013241206809
# test mse = 162.14245125192653

# %%
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 95.99%
# The testing accuracy is 64.32%

# %% [markdown]
# ## XGBoost

# %%
import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
from xgboost import XGBRegressor

reg = XGBRegressor(n_estimators=1000, learning_rate=0.04)
reg.fit(train_x.values, train_y.WinMargin.values)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.04, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(reg.predict(train_x.values))
test_y2['prediction'] = sc2.inverse_transform(reg.predict(test_x.values))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'XGBoost Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'XGBoost Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'XGBoost Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'XGBoost Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.3788611999777476
# train mse = 111.26047534593958
# adj test r^2 = 0.15316052731387175
# test mse = 158.92226660934907

# %%
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 72.99%
# The testing accuracy is 64.73%

# %% [markdown]
# ## Feed Forward Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.models import load_model
from keras.layers import LSTM
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
K.clear_session()
model = Sequential()
model.add(Dense(32, input_dim=23, activation='tanh'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='Adam', loss='mean_squared_error')
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=0, min_delta=.000001,restore_best_weights=True)
        
out = model.fit(train_x.values, train_y.WinMargin.values.ravel(), validation_data=[test_x.values, test_y['WinMargin'].values.ravel()], epochs=100,verbose=1,shuffle=False)
# Out:
# Train on 6750 samples, validate on 1687 samples
# Epoch 1/100
# 6750/6750 [==============================] - 1s 153us/step - loss: 0.8727 - val_loss: 0.8904
# Epoch 2/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7971 - val_loss: 0.8845
# Epoch 3/100
# 6750/6750 [==============================] - 0s 45us/step - loss: 0.7851 - val_loss: 0.8788
# Epoch 4/100
# 6750/6750 [==============================] - 0s 45us/step - loss: 0.7801 - val_loss: 0.8790
# Epoch 5/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7770 - val_loss: 0.8782
# Epoch 6/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7747 - val_loss: 0.8762
# Epoch 7/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7728 - val_loss: 0.8744
# Epoch 8/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7707 - val_loss: 0.8716
# Epoch 9/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7695 - val_loss: 0.8722
# Epoch 10/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7690 - val_loss: 0.8734
# Epoch 11/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7678 - val_loss: 0.8738
# Epoch 12/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7666 - val_loss: 0.8749
# Epoch 13/100
# 6750/6750 [==============================] - 0s 49us/step - loss: 0.7660 - val_loss: 0.8747
# Epoch 14/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7647 - val_loss: 0.8750
# Epoch 15/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7644 - val_loss: 0.8753
# Epoch 16/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7632 - val_loss: 0.8751
# Epoch 17/100
# 6750/6750 [==============================] - 0s 50us/step - loss: 0.7626 - val_loss: 0.8757
# Epoch 18/100
# 6750/6750 [==============================] - 0s 58us/step - loss: 0.7618 - val_loss: 0.8751
# Epoch 19/100
# 6750/6750 [==============================] - 0s 55us/step - loss: 0.7609 - val_loss: 0.8752
# Epoch 20/100
# 6750/6750 [==============================] - 0s 53us/step - loss: 0.7601 - val_loss: 0.8756
# Epoch 21/100
# 6750/6750 [==============================] - 0s 65us/step - loss: 0.7594 - val_loss: 0.8762
# Epoch 22/100
# 6750/6750 [==============================] - 0s 57us/step - loss: 0.7585 - val_loss: 0.8754
# Epoch 23/100
# 6750/6750 [==============================] - 0s 52us/step - loss: 0.7579 - val_loss: 0.8763
# Epoch 24/100
# 6750/6750 [==============================] - 0s 54us/step - loss: 0.7574 - val_loss: 0.8757
# Epoch 25/100
# 6750/6750 [==============================] - 0s 64us/step - loss: 0.7565 - val_loss: 0.8754
# Epoch 26/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7560 - val_loss: 0.8753
# Epoch 27/100
# 6750/6750 [==============================] - 0s 52us/step - loss: 0.7548 - val_loss: 0.8748
# Epoch 28/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7542 - val_loss: 0.8763
# Epoch 29/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7535 - val_loss: 0.8760
# Epoch 30/100
# 6750/6750 [==============================] - 0s 50us/step - loss: 0.7531 - val_loss: 0.8770
# Epoch 31/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7522 - val_loss: 0.8774
# Epoch 32/100
# 6750/6750 [==============================] - 0s 62us/step - loss: 0.7514 - val_loss: 0.8778
# Epoch 33/100
# 6750/6750 [==============================] - 0s 58us/step - loss: 0.7506 - val_loss: 0.8773
# Epoch 34/100
# 6750/6750 [==============================] - 0s 54us/step - loss: 0.7500 - val_loss: 0.8797
# Epoch 35/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7493 - val_loss: 0.8794
# Epoch 36/100
# 6750/6750 [==============================] - 0s 49us/step - loss: 0.7488 - val_loss: 0.8804
# Epoch 37/100
# 6750/6750 [==============================] - 0s 49us/step - loss: 0.7482 - val_loss: 0.8809
# Epoch 38/100
# 6750/6750 [==============================] - 0s 63us/step - loss: 0.7477 - val_loss: 0.8813
# Epoch 39/100
# 6750/6750 [==============================] - 0s 66us/step - loss: 0.7472 - val_loss: 0.8827
# Epoch 40/100
# 6750/6750 [==============================] - 0s 51us/step - loss: 0.7461 - val_loss: 0.8814
# Epoch 41/100
# 6750/6750 [==============================] - 0s 71us/step - loss: 0.7454 - val_loss: 0.8821
# Epoch 42/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7451 - val_loss: 0.8804
# Epoch 43/100
# 6750/6750 [==============================] - 0s 54us/step - loss: 0.7442 - val_loss: 0.8824
# Epoch 44/100
# 6750/6750 [==============================] - 0s 52us/step - loss: 0.7435 - val_loss: 0.8824
# Epoch 45/100
# 6750/6750 [==============================] - 0s 65us/step - loss: 0.7426 - val_loss: 0.8827
# Epoch 46/100
# 6750/6750 [==============================] - 0s 54us/step - loss: 0.7416 - val_loss: 0.8835
# Epoch 47/100
# 6750/6750 [==============================] - 0s 52us/step - loss: 0.7409 - val_loss: 0.8845
# Epoch 48/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7401 - val_loss: 0.8848
# Epoch 49/100
# 6750/6750 [==============================] - 0s 55us/step - loss: 0.7396 - val_loss: 0.8863
# Epoch 50/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7388 - val_loss: 0.8852
# Epoch 51/100
# 6750/6750 [==============================] - 0s 64us/step - loss: 0.7377 - val_loss: 0.8863
# Epoch 52/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7372 - val_loss: 0.8872
# Epoch 53/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7365 - val_loss: 0.8869
# Epoch 54/100
# 6750/6750 [==============================] - 0s 51us/step - loss: 0.7357 - val_loss: 0.8876
# Epoch 55/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7350 - val_loss: 0.8886
# Epoch 56/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7347 - val_loss: 0.8893
# Epoch 57/100
# 6750/6750 [==============================] - 0s 57us/step - loss: 0.7339 - val_loss: 0.8896
# Epoch 58/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7327 - val_loss: 0.8905
# Epoch 59/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7321 - val_loss: 0.8897
# Epoch 60/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7316 - val_loss: 0.8912
# Epoch 61/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7310 - val_loss: 0.8923
# Epoch 62/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7301 - val_loss: 0.8932
# Epoch 63/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7294 - val_loss: 0.8917
# Epoch 64/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7287 - val_loss: 0.8920
# Epoch 65/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7275 - val_loss: 0.8917
# Epoch 66/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7273 - val_loss: 0.8919
# Epoch 67/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7264 - val_loss: 0.8932
# Epoch 68/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7259 - val_loss: 0.8933
# Epoch 69/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7253 - val_loss: 0.8932
# Epoch 70/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7243 - val_loss: 0.8944
# Epoch 71/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7237 - val_loss: 0.8947
# Epoch 72/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7228 - val_loss: 0.8951
# Epoch 73/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7224 - val_loss: 0.8956
# Epoch 74/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7220 - val_loss: 0.8967
# Epoch 75/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7212 - val_loss: 0.8970
# Epoch 76/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7205 - val_loss: 0.8972
# Epoch 77/100
# 6750/6750 [==============================] - 0s 47us/step - loss: 0.7202 - val_loss: 0.8983
# Epoch 78/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7196 - val_loss: 0.8990
# Epoch 79/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7188 - val_loss: 0.9002
# Epoch 80/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7180 - val_loss: 0.9009
# Epoch 81/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7181 - val_loss: 0.9016
# Epoch 82/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7173 - val_loss: 0.9026
# Epoch 83/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7170 - val_loss: 0.9035
# Epoch 84/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7157 - val_loss: 0.9054
# Epoch 85/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7157 - val_loss: 0.9051
# Epoch 86/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7146 - val_loss: 0.9071
# Epoch 87/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7145 - val_loss: 0.9091
# Epoch 88/100
# 6750/6750 [==============================] - 0s 48us/step - loss: 0.7138 - val_loss: 0.9095
# Epoch 89/100
# 6750/6750 [==============================] - 0s 54us/step - loss: 0.7131 - val_loss: 0.9094
# Epoch 90/100
# 6750/6750 [==============================] - 0s 45us/step - loss: 0.7125 - val_loss: 0.9104
# Epoch 91/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7117 - val_loss: 0.9107
# Epoch 92/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7114 - val_loss: 0.9133
# Epoch 93/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7105 - val_loss: 0.9144
# Epoch 94/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7099 - val_loss: 0.9137
# Epoch 95/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7092 - val_loss: 0.9135
# Epoch 96/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7084 - val_loss: 0.9161
# Epoch 97/100
# 6750/6750 [==============================] - 0s 46us/step - loss: 0.7084 - val_loss: 0.9159
# Epoch 98/100
# 6750/6750 [==============================] - 0s 68us/step - loss: 0.7071 - val_loss: 0.9171
# Epoch 99/100
# 6750/6750 [==============================] - 0s 65us/step - loss: 0.7068 - val_loss: 0.9179
# Epoch 100/100
# 6750/6750 [==============================] - 0s 49us/step - loss: 0.7059 - val_loss: 0.9191

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(model.predict(train_x.values))
test_y2['prediction'] = sc2.inverse_transform(model.predict(test_x.values))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'NN Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'NN Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'NN Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'NN Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.29569400596811457
# train mse = 126.15766344362122
# adj test r^2 = 0.11130884555248122
# test mse = 166.776369236186

# %%
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 70.14%
# The testing accuracy is 66.35%

# %% [markdown]
# ## LSTM

# %%
X_tr_t = train_x.values.reshape(train_x.shape[0], 1, train_x.shape[1])
X_tst_t = test_x.values.reshape(test_x.shape[0], 1, test_x.shape[1])

# %%
K.clear_session()
model_lstm = Sequential()
model_lstm.add(LSTM(600, input_shape=(1, train_x.values.shape[1]), activation='linear',kernel_initializer='lecun_uniform'))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
history_model_lstm = model_lstm.fit(X_tr_t, train_y.WinMargin.values.ravel(), validation_data=[X_tst_t, test_y['WinMargin'].values.ravel()], epochs=10, verbose=1, shuffle=False)
# Out:
# Train on 6750 samples, validate on 1687 samples
# Epoch 1/10
# 6750/6750 [==============================] - 19s 3ms/step - loss: 0.8566 - val_loss: 0.8915
# Epoch 2/10
# 6750/6750 [==============================] - 16s 2ms/step - loss: 0.8045 - val_loss: 0.8923
# Epoch 3/10
# 6750/6750 [==============================] - 17s 3ms/step - loss: 0.8016 - val_loss: 0.8792
# Epoch 4/10
# 6750/6750 [==============================] - 17s 2ms/step - loss: 0.7893 - val_loss: 0.8705
# Epoch 5/10
# 6750/6750 [==============================] - 17s 3ms/step - loss: 0.7860 - val_loss: 0.8758
# Epoch 6/10
# 6750/6750 [==============================] - 18s 3ms/step - loss: 0.7832 - val_loss: 0.8771
# Epoch 7/10
# 6750/6750 [==============================] - 17s 3ms/step - loss: 0.7810 - val_loss: 0.8766
# Epoch 8/10
# 6750/6750 [==============================] - 17s 2ms/step - loss: 0.7793 - val_loss: 0.8752
# Epoch 9/10
# 6750/6750 [==============================] - 16s 2ms/step - loss: 0.7778 - val_loss: 0.8735
# Epoch 10/10
# 6750/6750 [==============================] - 17s 2ms/step - loss: 0.7764 - val_loss: 0.8711

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(model_lstm.predict(X_tr_t))
test_y2['prediction'] = sc2.inverse_transform(model_lstm.predict(X_tst_t))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'LSTM Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'LSTM Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'LSTM Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'LSTM Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.22107303436219372
# train mse = 139.5240233801655
# adj test r^2 = 0.15776514175716372
# test mse = 158.05814089509894

# %%
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 68.34%
# The testing accuracy is 63.37%

# %% [markdown]
# ## TPOT

# %%
from tpot import TPOTRegressor

tpot = TPOTRegressor(population_size=5, max_time_mins=2, verbosity=2, config_dict='TPOT light')
tpot.fit(train_x.values, train_y.WinMargin.values.ravel())
# Out:
# /anaconda3/lib/python3.7/site-packages/deap/tools/_hypervolume/pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=5, style=ProgressStyle(descriptio…
# Generation 1 - Current best internal CV score: -0.7751870524116475
# Generation 2 - Current best internal CV score: -0.7751870524116475
# Generation 3 - Current best internal CV score: -0.7740138767060228
# Generation 4 - Current best internal CV score: -0.7740025775081683
# Generation 5 - Current best internal CV score: -0.7740025775081683
# Generation 6 - Current best internal CV score: -0.7735852287564584
# Generation 7 - Current best internal CV score: -0.7735852287564584
# Generation 8 - Current best internal CV score: -0.7735852287564584
# Generation 9 - Current best internal CV score: -0.7735852287564584
# Generation 10 - Current best internal CV score: -0.7735852287564584
# Generation 11 - Current best internal CV score: -0.7735852287564584
# Generation 12 - Current best internal CV score: -0.7735852287564584
# Generation 13 - Current best internal CV score: -0.7735852287564584
# Generation 14 - Current best internal CV score: -0.7735852287564584
# Generation 15 - Current best internal CV score: -0.7735852287564584
# Generation 16 - Current best internal CV score: -0.7735852287564584
# Generation 17 - Current best internal CV score: -0.7735852287564584
# Generation 18 - Current best internal CV score: -0.7735852287564584
# Generation 19 - Current best internal CV score: -0.7735852287564584
# Generation 20 - Current best internal CV score: -0.7735852287564584
# Generation 21 - Current best internal CV score: -0.7734737573706897
# Generation 22 - Current best internal CV score: -0.7733477520154755
# Generation 23 - Current best internal CV score: -0.7733477520154755
# Generation 24 - Current best internal CV score: -0.7733477520154755
# Generation 25 - Current best internal CV score: -0.7733477520154755
# Generation 26 - Current best internal CV score: -0.773212215140244
# Generation 27 - Current best internal CV score: -0.773212215140244
# Generation 28 - Current best internal CV score: -0.773212215140244
# Generation 29 - Current best internal CV score: -0.773212215140244
# Generation 30 - Current best internal CV score: -0.773212215140244
# Generation 31 - Current best internal CV score: -0.773212215140244
# Generation 32 - Current best internal CV score: -0.773212215140244
# Generation 33 - Current best internal CV score: -0.773212215140244
# Generation 34 - Current best internal CV score: -0.773212215140244
# Generation 35 - Current best internal CV score: -0.7732083942958952
# Generation 36 - Current best internal CV score: -0.773191885981028
# Generation 37 - Current best internal CV score: -0.773191885981028
# Generation 38 - Current best internal CV score: -0.773191885981028
# Generation 39 - Current best internal CV score: -0.773191885981028
# Generation 40 - Current best internal CV score: -0.7731525339059618
# Generation 41 - Current best internal CV score: -0.7731525339059618
# Generation 42 - Current best internal CV score: -0.7731525339059618
# Generation 43 - Current best internal CV score: -0.7731280220967964
#
# 2.012029216666667 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: LinearSVR(ElasticNetCV(MaxAbsScaler(input_matrix), l1_ratio=0.55, tol=0.1), C=0.01, dual=False, epsilon=0.01, loss=squared_epsilon_insensitive, tol=0.01)
# TPOTRegressor(config_dict='TPOT light', crossover_rate=0.1, cv=5,
#        disable_update_check=False, early_stop=None, generations=1000000,
#        max_eval_time_mins=5, max_time_mins=2, memory=None,
#        mutation_rate=0.9, n_jobs=1, offspring_size=None,
#        periodic_checkpoint_folder=None, population_size=5,
#        random_state=None, scoring=None, subsample=1.0,
#        template='RandomTree', use_dask=False, verbosity=2,
#        warm_start=False)

# %%
train_y2 = train_y.copy(deep=True)
test_y2 = test_y.copy(deep=True)
train_y2['prediction'] = sc2.inverse_transform(tpot.predict(train_x.values))
test_y2['prediction'] = sc2.inverse_transform(tpot.predict(test_x.values))
train_y2['WinMargin'] = sc2.inverse_transform(train_y2['WinMargin'])
test_y2['WinMargin'] = sc2.inverse_transform(test_y2['WinMargin'])
train_y2['WinMargin'].plot(figsize=(15,7), title= 'TPOT Training', fontsize=14, label='True Value')
train_y2['prediction'].plot(figsize=(15,7), title= 'TPOT Training', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj train r^2 = ' + str(adj_r2_score((r2_score(train_y2.WinMargin, train_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('train mse = ' + str(mean_squared_error(train_y2.WinMargin, train_y2.prediction)))
test_y2['WinMargin'].plot(figsize=(15,7), title= 'TPOT Testing', fontsize=14, label='True Value')
test_y2['prediction'].plot(figsize=(15,7), title= 'TPOT Testing', fontsize=14, label='Prediction')
plt.legend(loc='lower left')
plt.show()
print('adj test r^2 = ' + str(adj_r2_score((r2_score(test_y2.WinMargin, test_y2.prediction)),train_x.shape[0], train_x.shape[1])))
print('test mse = ' + str(mean_squared_error(test_y2.WinMargin, test_y2.prediction)))
# Out:
# adj train r^2 = 0.21974561576901253
# train mse = 139.76179507250717
# adj test r^2 = 0.19027768198250428
# test mse = 151.95666977513633

# %%
train_y3 = train_y2.copy(deep=True)
test_y3 = test_y2.copy(deep=True)
train_y3.loc[train_y3['prediction'] > train_x['average'], 'PredOver'] = 1
train_y3.loc[train_y3['prediction'] <= train_x['average'], 'PredOver'] = 0
train_y3.loc[train_y3['WinMargin'] > train_x['average'], 'Over'] = 1
train_y3.loc[train_y3['WinMargin'] <= train_x['average'], 'Over'] = 0
test_y3.loc[test_y3['prediction'] > test_x['average'], 'PredOver'] = 1
test_y3.loc[test_y3['prediction'] <= test_x['average'], 'PredOver'] = 0
test_y3.loc[test_y3['WinMargin'] > test_x['average'], 'Over'] = 1
test_y3.loc[test_y3['WinMargin'] <= test_x['average'], 'Over'] = 0
trainaccuracy =  accuracy_score(train_y3['PredOver'].values, train_y3['Over'].values) * 100
print('The training accuracy is ' + str(round(trainaccuracy,2)) + '%')
testaccuracy =  accuracy_score(test_y3['PredOver'].values, test_y3['Over'].values) * 100
print('The testing accuracy is ' + str(round(testaccuracy,2)) + '%')
# Out:
# The training accuracy is 68.33%
# The testing accuracy is 67.75%
